# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
import kde_function as f

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

import seaborn as sns

import matplotlib
# %matplotlib inline

import glob

# %% [markdown]
# ### First, let's look at our KDE maps over time to get a sense of where tornado alley is shifting

# %%
import geopandas as gpd
states = gpd.read_file(
    "https://www2.census.gov/geo/tiger/GENZ2023/shp/cb_2023_us_state_20m.zip" # reads in state lines to plot
)

states = states[
    ~states["STUSPS"].isin(["PR", "GU", "VI", "AS", "MP"]) # instructing to plot US and exclude Puerto Rico, Guam, etc since we don't have this data
]

import glob
df_all = glob.glob('../data/processed/per_year/*_tornados.csv')

df_all = np.sort(df_all)

fig, ax = plt.subplots(len(df_all),1, figsize=(7,5*len(df_all)))
fig.subplots_adjust(hspace=0.45)

Ntornados = []
year = []
for n in range(0,len(df_all)):
    print(df_all[n])
    df = pd.read_csv(df_all[n])
    year.append(df['YEAR'][0])
    Ntornados.append(len(df))
    xx, yy, zz = f.kde2D(df['BEGIN_LON'],df['BEGIN_LAT'], 1.0)
    ax[n].contourf(
        xx,
        yy,
        zz,
        levels=10,
        cmap="Reds",
        alpha=0.8
    )
    
    states.boundary.plot(
        ax=ax[n],#plt.gca(),
        color="black",
        linewidth=0.5
    )
    
    ax[n].set_xlim(-125, -66)
    ax[n].set_ylim(24, 50)
    
    ax[n].set_xlabel('LON [$^\circ$]')
    ax[n].set_ylabel('LAT [$^\circ$]')
    
    ax[n].set_title('Tornado Locations in '+str(df['YEAR'][0])+', N='+str(len(df['BEGIN_LON'])))

fig.savefig('../plots/kde-tornadoes-time.pdf')
# Out:
# <>:44: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\c'
# <>:44: SyntaxWarning: invalid escape sequence '\c'
# <>:45: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_433674/87803071.py:44: SyntaxWarning: invalid escape sequence '\c'
#   ax[n].set_xlabel('LON [$^\circ$]')
# /tmp/ipykernel_433674/87803071.py:45: SyntaxWarning: invalid escape sequence '\c'
#   ax[n].set_ylabel('LAT [$^\circ$]')
# ../data/processed/per_year/1990_tornados.csv
# ../data/processed/per_year/1991_tornados.csv
# ../data/processed/per_year/1992_tornados.csv
# ../data/processed/per_year/1993_tornados.csv
# ../data/processed/per_year/1994_tornados.csv
# ../data/processed/per_year/1995_tornados.csv
# ../data/processed/per_year/1996_tornados.csv
# ../data/processed/per_year/1997_tornados.csv
# ../data/processed/per_year/1998_tornados.csv
# ../data/processed/per_year/1999_tornados.csv
# ../data/processed/per_year/2000_tornados.csv
# ...

# %% [markdown]
# ## Autocorrelation: is our data seasonal or exhibits some type of trend?

# %%
import statsmodels.api as sm
fig, ax = plt.subplots(1, 1, figsize=(8,4))
sm.graphics.tsa.plot_acf(Ntornados,
                            lags = 20,
                        ax=ax)

plt.title('Seasonality - Number of Tornados', fontsize=18)
plt.ylabel("Autocorrelation", fontsize=16)
plt.xlabel("Lag", fontsize=16)
# Out:
# Text(0.5, 0, 'Lag')

# %%
plt.figure()
plt.plot(year, Ntornados)
plt.xlabel('Year')
plt.ylabel('Tornados per year')

ind = int(len(Ntornados)*0.8)

trend_train = Ntornados[:ind]
trend_test = Ntornados[ind:]


from sklearn.linear_model import LinearRegression
train_times = np.array(year[:ind]).reshape(-1,1)
forecast_times =  np.array(year[ind:]).reshape(-1,1)

linear_trend_reg = LinearRegression()
linear_trend_reg.fit(train_times,trend_train)
linear_trend_forecast = linear_trend_reg.predict(forecast_times)

plt.figure()
plt.plot(train_times, trend_train, label = 'Train Data')
plt.plot(forecast_times, trend_test, label = 'Test Data')
plt.plot(forecast_times, linear_trend_forecast, '--k', label = 'Linear Trend Forecast')
plt.legend(fontsize=10)
plt.xlabel('Year')
plt.ylabel('Tornados per year')
# Out:
# Text(0, 0.5, 'Tornados per year')

# %%
df = pd.read_csv('../data/processed/years_season_EFscale.csv', index_col=0)
dfall = pd.read_csv('../data/processed/tornadoes_all.csv', index_col=0)

# %%
dfall
# Out:
#        YEAR  MONTH  BEGIN_LAT  BEGIN_LON  TOR_F_SCALE
# 0      1990      6    44.3700   -92.6300            1
# 1      1990      5    42.0800   -71.4000            0
# 2      1990      6    41.1000   -98.4700            0
# 3      1990      6    41.5200   -97.7300            0
# 4      1990      6    40.2500  -100.7500            4
# ...     ...    ...        ...        ...          ...
# 48229  2025      9    48.2490  -100.8390           -1
# 48230  2025      6    37.2391   -98.0398            0
# 48231  2025      9    47.1400  -100.1750           -1
# 48232  2025      6    36.1732  -101.1485            2
# 48233  2025      6    36.0861   -95.1784            1
#
# [48234 rows x 5 columns]

# %%
df
# Out:
#     year   EF0  EF1  EF2  EF3  EF4  EF5  Nspring  Nsummer  Nautumn  Nwinter
# 0   1990   541  412  190   71   42    8      329      235       73       86
# 1   1991   694  313  128   61   10    2      360       91       40       23
# 2   1992   707  447  151   67   30    2      119      321      219       38
# 3   1993   242  134   37    7    3    0       92       27       45       17
# 4   1994   381  144   42   10    4    0       76       89       31        4
# 5   1995   478  168   57   13    9    0      147       50       32       18
# 6   1996   765  341  102   26    3    1      225      118       97       33
# 7   1997   756  294   89   31    9    1      169      131       75       49
# 8   1998   914  416  137   48   11    3      271      189       94       61
# 9   1999   885  381  164   69   16    2      311      135       24      162
# 10  2000   755  290   82   27    3    0      202       74       70       56
# ...

# %% [markdown]
# ###  Reference for trends over longer period of time: https://repository.library.noaa.gov/view/noaa/69284

# %%
df = pd.read_csv('../data/processed/years_season_EFscale.csv', index_col=0)
dfall = pd.read_csv('../data/processed/tornadoes_all.csv', index_col=0)
plt.figure()
plt.plot(df.year, df.Nspring, label='spring')
plt.plot(df.year, df.Nsummer, label='summer')
plt.plot(df.year, df.Nautumn, label='autumn')
plt.plot(df.year, df.Nwinter, label='winter')
plt.xlabel('Year')
plt.legend(loc='upper right', bbox_to_anchor=(1.37, 1.03))
plt.ylabel('Number of Events')
plt.yscale('log')

# %%
df = pd.read_csv('../data/processed/years_season_EFscale.csv', index_col=0)
dfall = pd.read_csv('../data/processed/tornadoes_all.csv', index_col=0)
plt.figure()
plt.plot(df.year, df.EF0, label='EF0')
plt.plot(df.year, df.EF1, label='EF1')
plt.plot(df.year, df.EF2, label='EF2')
plt.plot(df.year, df.EF3, label='EF3')
plt.plot(df.year, df.EF4, label='EF4')
plt.plot(df.year, df.EF5, label='EF5')
plt.legend(loc='upper right', bbox_to_anchor=(1.27, 1.03))
plt.xlabel('Year')
plt.ylabel('Number of Events')
# Out:
# Text(0, 0.5, 'Number of Events')

# %%
#### PARAMETRIC LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

parametric_model = LinearRegression()
parametric_model.fit(np.array(df.year).reshape(-1,1), df.Nspring)
parametric_predictions = parametric_model.predict(np.array(df.year).reshape(-1,1))
parametric_mse = mean_squared_error(df.Nspring, parametric_predictions)
print(parametric_mse)
# Out:
# 24687.636404261415

# %%
#### NONPARAMETRIC REGRESSION
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV

nonparametric_model = KernelRidge(kernel='rbf')
param_grid = {"alpha":    [10**(-k) for k in range(-5, 5)],
              "gamma": [10**(k) for k in range(-5,5)]}

search = GridSearchCV(nonparametric_model, param_grid, cv=5).fit(np.array(df.year).reshape(-1,1), df.Nspring)

print("The best hyperparameters are ",search.best_params_)
# Out:
# The best hyperparameters are  {'alpha': 10, 'gamma': 0.0001}

# %%
nonparametric_model = KernelRidge(kernel = 'rbf', **search.best_params_) # ** "unpacks" the dict of params into kwarg assignments
nonparametric_model.fit(np.array(df.year).reshape(-1,1), df.Nspring)
nonparametric_predictions = nonparametric_model.predict(np.array(df.year).reshape(-1,1))
nonparametric_mse = mean_squared_error(df.Nspring, nonparametric_predictions)
print(nonparametric_mse)
# Out:
# 34558.68616152455

# %% [markdown]
# ### It seems like neither of the models are doing very well in fitting our data

# %%
plt.scatter(np.array(df.year).reshape(-1,1), df.Nspring)

xs_for_plotting = np.linspace(np.array(df.year).min() - 1, np.array(df.year).max() + 1)

plt.plot(xs_for_plotting, parametric_model.predict(xs_for_plotting.reshape(-1,1)), 'k', label = 'parametric model')
plt.plot(xs_for_plotting, nonparametric_model.predict(xs_for_plotting.reshape(-1,1)), 'r', label = 'nonparametric model')

plt.xlabel('Year')
plt.ylabel('# Tornadoes in Spring')
plt.legend(loc = 'upper left')

plt.show()

# %% [markdown]
# ### The linear regression and non-parametric model both have large MSE's, likely due to the extreme number of tornadoes in 2011

# %% [markdown]
# ###  Feature engineering -- the log of events shows a clearer overall trend

# %%
df = pd.read_csv('../data/processed/years_season_EFscale.csv', index_col=0)
dfall = pd.read_csv('../data/processed/tornadoes_all.csv', index_col=0)

df.Nspring = np.log10(df.Nspring)
df.Nsummer = np.log10(df.Nsummer)
df.Nautumn = np.log10(df.Nautumn)
df.Nwinter = np.log10(df.Nwinter)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, KFold

# %%
para_slopes_all = []
para_slopes_lo = []
para_slopes_hi = []
para_int_all = []

nonpara_slopes_all = []
nonpara_slopes_lo = []
nonpara_slopes_hi = []
nonpara_int_all = []

para_mse_all = []
nonpara_mse_all = []

from scipy import stats

colors = ['green', 'orange', 'red', 'royalblue']
seasons = ['spring', 'summer', 'autumn', 'winter']
markers = ['o', '^', 's', '>']
Y_all = [df.Nspring, df.Nsummer, df.Nautumn, df.Nwinter]

fig, ax = plt.subplots(4,1,figsize=(8,12))
for n in range(0,4):
    X = np.array(df.year).reshape(-1,1)
    Y = Y_all[n]

    
    print('============= STARTING PARAMETRIC MODEL =============')
    parametric_model = LinearRegression()
    parametric_model.fit(X,Y)
    parametric_predictions = parametric_model.predict(X)
    parametric_mse = mean_squared_error(Y, parametric_predictions)
    print('MSE = ', parametric_mse)
    
    para_slope = parametric_model.coef_[0]
    para_intercept = parametric_model.intercept_

    para_slopes_all.append(para_slope)
    para_int_all.append(para_intercept)
    
    print('slope = ', para_slope, 'intercept = ', para_intercept)
    
    Ndata = len(X)
    dof = Ndata - 2 
    
    # critical t-value for 95% confidence
    t_critical = stats.t.ppf(0.975, df=dof)
    
    # Calculate Residual Standard Error (RSE)
    y_pred = parametric_model.predict(X)
    residuals = Y - parametric_predictions
    rse = np.sqrt(np.sum(residuals**2) / dof)
    
    # Calculate Standard Error of the slope
    x_mean = np.mean(X)
    ss_x = np.sum((X - x_mean)**2)
    se_slope = rse / np.sqrt(ss_x)
    
    margin_of_error = t_critical * se_slope
    lower_bound = para_slope - margin_of_error
    upper_bound = para_slope + margin_of_error
    
    #print(f"Slope: {para_slope}")
    print(f"95% CI for slope: [{lower_bound}, {upper_bound}]")

    para_slopes_lo.append(lower_bound)
    para_slopes_hi.append(upper_bound)

    #################################################
    ####### nonparametric model
    #################################################

    print('============= STARTING NON-PARAMETRIC MODEL =============')
    
    nonparametric_model = KernelRidge(kernel='rbf')
    param_grid = {"alpha":    [10**(-k) for k in range(-5, 5)],
                  "gamma": [10**(k) for k in range(-5,5)]}
    
    search = GridSearchCV(nonparametric_model, param_grid, cv=5).fit(X, Y)
    
    print("The best hyperparameters are ",search.best_params_)

    nonparametric_model = KernelRidge(kernel = 'rbf', **search.best_params_) # ** "unpacks" the dict of params into kwarg assignments
    nonparametric_model.fit(X, Y)
    nonparametric_predictions = nonparametric_model.predict(X)
    nonparametric_mse = mean_squared_error(Y, nonparametric_predictions)
    print('MSE = ', nonparametric_mse)

    #plt.figure()
    ax[n].plot(np.array(df.year).reshape(-1,1), 10**(Y), color=colors[n], label=seasons[n], linestyle='-', linewidth = 1)

    xs_for_plotting = np.linspace(np.array(df.year).min() - 1, np.array(df.year).max() + 1)

    # if n == 3:
    #     ax[n].plot(xs_for_plotting, parametric_model.predict(xs_for_plotting.reshape(-1,1)), linestyle='-.', color=colors[n], label = 'parametric model')
    #     ax[n].plot(xs_for_plotting, nonparametric_model.predict(xs_for_plotting.reshape(-1,1)), linestyle='dashed', color=colors[n], label = 'nonparametric model')
    # else:
    ax[n].plot(xs_for_plotting, 10**(parametric_model.predict(xs_for_plotting.reshape(-1,1))), linewidth = 2, color=colors[n],  label = 'parametric')
    ax[n].plot(xs_for_plotting, 10**(nonparametric_model.predict(xs_for_plotting.reshape(-1,1))), linestyle='dashed', color=colors[n],  label = 'nonparametric')

    ax[n].set_xlabel('Year')
    ax[n].set_ylabel('# Tornadoes')
    ax[n].set_yscale('log')
    ax[n].annotate('y=s*log$_{10}$(X)+B', xy=(1.01, 0.4), xycoords='axes fraction', fontsize=14)
    ax[n].annotate('s={:.3f}'.format(para_slope)+' $ \\pm $ '+'{:.3f}'.format(margin_of_error)+' dex/year', xy=(1.01, 0.3), xycoords='axes fraction', fontsize=14)
    ax[n].annotate('MSE$_{para.}$'+'={:.4f}'.format(parametric_mse), xy=(1.01, 0.18), xycoords='axes fraction', fontsize=14)
    ax[n].annotate('MSE$_{nonpara.}$'+'={:.4f}'.format(nonparametric_mse), xy=(1.01, 0.08), xycoords='axes fraction', fontsize=14)
    
    ax[n].legend(loc = 'upper left', fontsize=14, bbox_to_anchor= (0.99,1.05))

fig.savefig('../plots/seasons_year.pdf', bbox_inches='tight')
# Out:
# ============= STARTING PARAMETRIC MODEL =============
# MSE =  0.043178621533946276
# slope =  0.011559104442104192 intercept =  -20.801095583840237
# 95% CI for slope: [0.004587598114393639, 0.018530610769814746]
# ============= STARTING NON-PARAMETRIC MODEL =============
# The best hyperparameters are  {'alpha': 0.01, 'gamma': 1e-05}
# MSE =  0.04347881485839786
# ============= STARTING PARAMETRIC MODEL =============
# MSE =  0.04672629054536211
# slope =  0.00503664186297984 intercept =  -8.030674337801187
# 95% CI for slope: [-0.002215610224349974, 0.012288893950309654]
# ============= STARTING NON-PARAMETRIC MODEL =============
# The best hyperparameters are  {'alpha': 0.001, 'gamma': 0.0001}
# MSE =  0.04532539496533439
# ============= STARTING PARAMETRIC MODEL =============
# MSE =  0.0795461687212537
# slope =  -0.0014756051490318733 intercept =  4.817811741790491
# 95% CI for slope: [-0.010938017564319308, 0.007986807266255561]
# ...

# %%
from sklearn.linear_model import QuantileRegressor
quantiles = [0.16, 0.50, 0.84]
qr_models = {}
for q in quantiles:
    qr = QuantileRegressor(quantile=q, alpha=0.0, solver="highs")
    qr.fit(X, Y)
    qr_models[q] = qr

# %%
X_plot = np.linspace(np.array(df.year).min() - 1, np.array(df.year).max() + 1, 10)

# %%
pred_lo  = qr_models[0.16].predict(X_plot.reshape(-1,1))
pred_med = qr_models[0.50].predict(X_plot.reshape(-1,1))
pred_hi  = qr_models[0.84].predict(X_plot.reshape(-1,1))

# %%
pred_lo, pred_med, pred_hi
# Out:
# (array([1.14014119, 1.21902746, 1.29791373, 1.37680001, 1.45568628,
#         1.53457255, 1.61345882, 1.69234509, 1.77123136, 1.85011764]),
#  array([1.31275169, 1.41342488, 1.51409808, 1.61477128, 1.71544447,
#         1.81611767, 1.91679087, 2.01746406, 2.11813726, 2.21881046]),
#  array([1.57604014, 1.67958578, 1.78313142, 1.88667707, 1.99022271,
#         2.09376836, 2.197314  , 2.30085965, 2.40440529, 2.50795093]))

# %%
plt.figure()
plt.plot(X, Y, label='winter')
plt.plot(X, parametric_model.predict(X))
plt.plot(X, nonparametric_model.predict(X))

#X_q = df_model.groupby("year")["BEGIN_LAT"].quantile([0.16, 0.50, 0.84]).unstack()
Y_q = Y.quantile([0.16, 0.50, 0.84])
Y_q

plt.fill_between(X_plot, pred_lo, pred_hi, alpha = 0.4)

# %%
scores = cross_val_score(parametric_model, X, Y, scoring='r2')
print(f"R2 scores for each fold: {scores}")
print(f"Mean R2 score: {scores.mean():.3f}")
print(f"Standard deviation: {scores.std():.3f}")
# Out:
# R2 scores for each fold: [-0.13230425 -0.22594877  0.01281023 -0.15783563 -0.13005456]
# Mean R2 score: -0.127
# Standard deviation: 0.078

# %%
from sklearn.model_selection import cross_validate

scoring_metrics = ['r2', 'neg_mean_squared_error']
cv_results = cross_validate(parametric_model, X, Y, cv=5, scoring=scoring_metrics)

print("Test R2 scores:", cv_results['test_r2'])
print("Test MSE scores:", -cv_results['test_neg_mean_squared_error'])
print(f"Mean R2 score: {cv_results['test_r2'].mean():.3f}")
print(f"Mean neg. MSE score: {cv_results['test_neg_mean_squared_error'].mean():.3f}")
# Out:
# Test R2 scores: [-0.13230425 -0.22594877  0.01281023 -0.15783563 -0.13005456]
# Test MSE scores: [0.15626395 0.17212303 0.06273818 0.05245401 0.05509576]
# Mean R2 score: -0.127
# Mean neg. MSE score: -0.100

# %%
para_slopes_all = []
para_slopes_lo = []
para_slopes_hi = []
para_int_all = []

para_residuals = []

nonpara_slopes_all = []
nonpara_slopes_lo = []
nonpara_slopes_hi = []
nonpara_int_all = []

nonpara_residuals = []

para_mse_all = []
nonpara_mse_all = []

from scipy import stats

colors = ['lightcoral', 'tomato', 'red', 'firebrick', 'maroon', 'brown']
labels = ['EF0', 'EF1', 'EF2', 'EF3', 'EF4', 'EF5']
Y_all = [df.EF0, df.EF1, df.EF2, df.EF3, df.EF4, df.EF5]

fig, ax = plt.subplots(6,1,figsize=(8,16))
for n in range(0,6):
    X = np.array(df.year).reshape(-1,1)
    Y = Y_all[n]

    
    print('============= STARTING PARAMETRIC MODEL =============')
    parametric_model = LinearRegression()
    parametric_model.fit(X,Y)
    parametric_predictions = parametric_model.predict(X)
    parametric_mse = mean_squared_error(Y, parametric_predictions)
    print('MSE = ', parametric_mse)
    
    para_slope = parametric_model.coef_[0]
    para_intercept = parametric_model.intercept_

    para_slopes_all.append(para_slope)
    para_int_all.append(para_intercept)
    
    print('slope = ', para_slope, 'intercept = ', para_intercept)
    
    Ndata = len(X)
    dof = Ndata - 2 
    
    # critical t-value for 95% confidence
    t_critical = stats.t.ppf(0.975, df=dof)
    
    # Calculate Residual Standard Error (RSE)
    y_pred = parametric_model.predict(X)
    residuals = Y - parametric_predictions
    rse = np.sqrt(np.sum(residuals**2) / dof)
    
    # Calculate Standard Error of the slope
    x_mean = np.mean(X)
    ss_x = np.sum((X - x_mean)**2)
    se_slope = rse / np.sqrt(ss_x)
    
    margin_of_error = t_critical * se_slope
    lower_bound = para_slope - margin_of_error
    upper_bound = para_slope + margin_of_error
    
    #print(f"Slope: {para_slope}")
    print(f"95% CI for slope: [{lower_bound}, {upper_bound}]")

    para_slopes_lo.append(lower_bound)
    para_slopes_hi.append(upper_bound)

    #################################################
    ####### nonparametric model
    #################################################

    print('============= STARTING NON-PARAMETRIC MODEL =============')
    
    nonparametric_model = KernelRidge(kernel='rbf')
    param_grid = {"alpha":    [10**(-k) for k in range(-5, 5)],
                  "gamma": [10**(k) for k in range(-5,5)]}
    
    search = GridSearchCV(nonparametric_model, param_grid, cv=5).fit(X, Y)
    
    print("The best hyperparameters are ",search.best_params_)

    nonparametric_model = KernelRidge(kernel = 'rbf', **search.best_params_) # ** "unpacks" the dict of params into kwarg assignments
    nonparametric_model.fit(X, Y)
    nonparametric_predictions = nonparametric_model.predict(X)
    nonparametric_mse = mean_squared_error(Y, nonparametric_predictions)
    print('MSE = ', nonparametric_mse)

    #plt.figure()
    ax[n].plot(np.array(df.year).reshape(-1,1), (Y), color=colors[n], label=labels[n], linestyle='-', linewidth = 1)

    xs_for_plotting = np.linspace(np.array(df.year).min() - 1, np.array(df.year).max() + 1)

    # if n == 3:
    #     ax[n].plot(xs_for_plotting, parametric_model.predict(xs_for_plotting.reshape(-1,1)), linestyle='-.', color=colors[n], label = 'parametric model')
    #     ax[n].plot(xs_for_plotting, nonparametric_model.predict(xs_for_plotting.reshape(-1,1)), linestyle='dashed', color=colors[n], label = 'nonparametric model')
    # else:
    ax[n].plot(xs_for_plotting, (parametric_model.predict(xs_for_plotting.reshape(-1,1))), linewidth = 2, color=colors[n],  label = 'parametric')
    ax[n].plot(xs_for_plotting, (nonparametric_model.predict(xs_for_plotting.reshape(-1,1))), linestyle='dashed', color=colors[n],  label = 'nonparametric')

    ax[n].set_xlabel('Year')
    ax[n].set_ylabel('# Tornadoes')
    ##ax[n].set_yscale('log')
    ax[n].annotate('y=s*X+B', xy=(1.01, 0.4), xycoords='axes fraction', fontsize=14)
    ax[n].annotate('s={:.3f}'.format(para_slope)+' $ \\pm $ '+'{:.3f}'.format(margin_of_error)+' 1/year', xy=(1.01, 0.3), xycoords='axes fraction', fontsize=14)
    ax[n].annotate('MSE$_{para.}$'+'={:.3e}'.format(parametric_mse), xy=(1.01, 0.18), xycoords='axes fraction', fontsize=14)
    ax[n].annotate('MSE$_{nonpara.}$'+'={:.3e}'.format(nonparametric_mse), xy=(1.01, 0.08), xycoords='axes fraction', fontsize=14)
    
    ax[n].legend(loc = 'upper left', fontsize=14, bbox_to_anchor= (0.99,1.1))

fig.savefig('../plots/EF_year.pdf', bbox_inches='tight')
# Out:
# ============= STARTING PARAMETRIC MODEL =============
# MSE =  35485.37755493589
# slope =  -1.8631917631917632 intercept =  4438.496353496354
# 95% CI for slope: [-8.183189959466922, 4.456806433083395]
# ============= STARTING NON-PARAMETRIC MODEL =============
# The best hyperparameters are  {'alpha': 0.1, 'gamma': 0.01}
# MSE =  19002.591989735964
# ============= STARTING PARAMETRIC MODEL =============
# MSE =  15615.71598384094
# slope =  10.305662805662806 intercept =  -20263.701415701413
# 95% CI for slope: [6.113161660446072, 14.49816395087954]
# ============= STARTING NON-PARAMETRIC MODEL =============
# The best hyperparameters are  {'alpha': 0.0001, 'gamma': 1e-05}
# MSE =  15209.564214640064
# ============= STARTING PARAMETRIC MODEL =============
# MSE =  1938.0461425711412
# slope =  1.3229086229086229 intercept =  -2531.155727155727
# 95% CI for slope: [-0.15407029248713178, 2.7998875383043775]
# ============= STARTING NON-PARAMETRIC MODEL =============
# ...

# %%
from sklearn.model_selection import cross_validate

scoring_metrics = ['r2', 'neg_mean_squared_error']
cv_results = cross_validate(nonparametric_model, X, Y, cv=5, scoring=scoring_metrics)

print("Test R2 scores:", cv_results['test_r2'])
print("Test MSE scores:", -cv_results['test_neg_mean_squared_error'])
print(f"Mean R2 score: {cv_results['test_r2'].mean():.3f}")
print(f"Mean neg. MSE score: {cv_results['test_neg_mean_squared_error'].mean():.3f}")
# Out:
# Test R2 scores: [-0.42969357 -0.18622752 -0.21235666 -0.00587991 -0.04574749]
# Test MSE scores: [ 8.84622895  1.59777584 17.12144508  0.12316897  0.12805071]
# Mean R2 score: -0.176
# Mean neg. MSE score: -5.563

# %%
para_slope = parametric_model.coef_[0]
para_intercept = parametric_model.intercept_
print(para_slope, para_intercept)
from scipy import stats

n = len(X)
dof = n - 2 

# critical t-value for 95% confidence
t_critical = stats.t.ppf(0.975, df=dof)

# Calculate Residual Standard Error (RSE)
y_pred = parametric_model.predict(X)
residuals = Y - parametric_predictions
rse = np.sqrt(np.sum(residuals**2) / dof)

# Calculate Standard Error of the slope
x_mean = np.mean(X)
ss_x = np.sum((X - x_mean)**2)
se_slope = rse / np.sqrt(ss_x)

margin_of_error = t_critical * se_slope
lower_bound = para_slope - margin_of_error
upper_bound = para_slope + margin_of_error

print(f"Slope: {para_slope}")
print(f"95% CI: [{lower_bound}, {upper_bound}]")
# Out:
# 0.011559104442104192 -20.801095583840237
# Slope: 0.011559104442104192
# 95% CI: [0.004587598114393639, 0.018530610769814746]

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV

nonparametric_model = KernelRidge(kernel='rbf')
param_grid = {"alpha":    [10**(-k) for k in range(-5, 5)],
              "gamma": [10**(k) for k in range(-5,5)]}

search = GridSearchCV(nonparametric_model, param_grid, cv=5).fit(np.array(df.year).reshape(-1,1), df.Nspring)

print("The best hyperparameters are ",search.best_params_)
# Out:
# The best hyperparameters are  {'alpha': 0.01, 'gamma': 1e-05}

# %%
nonparametric_model = KernelRidge(kernel = 'rbf', **search.best_params_) # ** "unpacks" the dict of params into kwarg assignments
nonparametric_model.fit(np.array(df.year).reshape(-1,1), df.Nspring)
nonparametric_predictions = nonparametric_model.predict(np.array(df.year).reshape(-1,1))
nonparametric_mse = mean_squared_error(df.Nspring, nonparametric_predictions)
print(nonparametric_mse)
# Out:
# 0.04347881485839786

# %%
plt.scatter(np.array(df.year).reshape(-1,1), df.Nspring)

xs_for_plotting = np.linspace(np.array(df.year).min() - 1, np.array(df.year).max() + 1)

plt.plot(xs_for_plotting, parametric_model.predict(xs_for_plotting.reshape(-1,1)), 'k', label = 'parametric model')
plt.plot(xs_for_plotting, nonparametric_model.predict(xs_for_plotting.reshape(-1,1)), 'r', label = 'nonparametric model')

plt.xlabel('Year')
plt.ylabel('log(# Tornadoes in Spring)')
plt.legend(loc = 'upper left')

plt.show()

# %%
# Residuals vs Year
residuals_para = parametric_model.predict(np.array(df.year).reshape(-1,1)) -  df.Nspring
plt.scatter(np.array(df.year).reshape(-1,1), residuals_para, label='parametric')
residuals_nonpara = nonparametric_model.predict(np.array(df.year).reshape(-1,1)) -  df.Nspring
plt.scatter(np.array(df.year).reshape(-1,1), residuals_nonpara, label='nonparametric')
plt.axhline(0, color='r', linestyle='--')
plt.legend(fontsize=14)
plt.xlabel("Year")
plt.ylabel("Residuals")
plt.title("Residuals vs Year")
# Out:
# Text(0.5, 1.0, 'Residuals vs Year')

# %%
# Residuals vs Predictions
residuals_para = parametric_model.predict(np.array(df.year).reshape(-1,1)) -  df.Nspring
plt.scatter(parametric_model.predict(np.array(df.year).reshape(-1,1)), residuals_para, label='parametric')
residuals_nonpara = nonparametric_model.predict(np.array(df.year).reshape(-1,1)) -  df.Nspring
plt.scatter(nonparametric_model.predict(np.array(df.year).reshape(-1,1)), residuals_nonpara, label='nonparametric')
plt.axhline(0, color='r', linestyle='--')
plt.legend(fontsize=14)
plt.xlabel("Prediction")
plt.ylabel("Residuals")
plt.title("Residuals vs Prediction")
# Out:
# Text(0.5, 1.0, 'Residuals vs Prediction')

# %%
from sklearn.metrics import RocCurveDisplay

# Plot the curve using your true binary outcomes and the prediction scores
RocCurveDisplay.from_predictions(y_test_binary, y_pred_continuous)
plt.show()

# %% [markdown]
# The parametric and non-parametric models exhibit a similar quality of fit to the data, which we can visualize with the above plot and by comparing the MSE's.

# %%
d_star = parametric_mse - nonparametric_mse
print(d_star)
# Out:
# -0.00030019332445158087

# %%
plt.figure()
plt.plot(np.arange(0,len(dfall)), dfall.MONTH, marker='.', linestyle='-')
plt.xlim([0,400])
# Out:
# (0.0, 400.0)
