# %%
import pandas as pd
import glob
import numpy as np
! pip install pandas plotly
! pip install geopandas matplotlib mapclassify
import plotly.io as pio
pio.renderers.default = "notebook_connected" # need this so the plots from plotly show up in the 

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})
import plotly.express as px

# %%
raw_files = glob.glob('~/summer26-twister/data/raw/StormEvents*')
raw_files = np.sort(raw_files) # will sort chronologically thanks to naming convention
print(raw_files)
# Out:
# ['./data/raw/StormEvents_details-ftp_v1.0_d1990_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1991_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1992_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1993_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1994_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1995_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1996_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1997_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1998_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1999_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2000_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2001_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2002_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2003_c20260323.csv.gz'
# ...

# %%
inFile = raw_files[10]
info = pd.read_csv(inFile, encoding = 'latin-1')

other, inYear = inFile.split('.0_d')
inYear, other = inYear.split('_c')
print(inYear)

print(info.keys())
# Out:
# 2000
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE'],
#       dtype='str')

# %%
info['BEGIN_YEARMONTH']
# Out:
# 0        200012
# 1        200012
# 2        200012
# 3        200012
# 4        200008
#           ...
# 52002    200001
# 52003    200001
# 52004    200002
# 52005    200002
# 52006    200001
# Name: BEGIN_YEARMONTH, Length: 52007, dtype: int64

# %%
# assess the quality of the data -- how many events have info on magnitude, deaths, damage, etc?
keys = ['MAGNITUDE', 'DEATHS_INDIRECT', 'BEGIN_LAT', 'END_LAT', 'BEGIN_LOCATION', 'END_LOCATION']
print('DATA FOR THE YEAR ', inYear)
for n in keys:
    Ntot = len(info[n])
    NnotNaN = Ntot - np.sum(info[n].isna()).astype(int)
    print(n, ' -- ', NnotNaN, 'out of ', Ntot,  ' are valid inputs, or {:.2f}%'.format(NnotNaN/Ntot*100))
# Out:
# DATA FOR THE YEAR  2000
# MAGNITUDE  --  20858 out of  52007  are valid inputs, or 40.11%
# DEATHS_INDIRECT  --  52007 out of  52007  are valid inputs, or 100.00%
# BEGIN_LAT  --  24320 out of  52007  are valid inputs, or 46.76%
# END_LAT  --  24320 out of  52007  are valid inputs, or 46.76%
# BEGIN_LOCATION  --  30511 out of  52007  are valid inputs, or 58.67%
# END_LOCATION  --  30511 out of  52007  are valid inputs, or 58.67%

# %% [markdown]
# ## Since we are focusing on tornados, we want to only select for Event type "C",
# according to this NOAA documentation about headers: https://www.ncei.noaa.gov/pub/data/swdi/stormevents/csvfiles/Storm-Data-Export-Format.pdf
#
# How many of these entries are from tornado events?
#
# Then we will filter the dataframe with only these events

# %%
len(info['EVENT_TYPE'][info['EVENT_TYPE'] == 'Tornado'])
# Out:
# 1169

# %%
Ntot = len(info[n])
Ntornado = np.sum(info['EVENT_TYPE'] == 'Tornado')
print(Ntornado, 'out of ', Ntot,  ' are tornado events, or {:.2f}%'.format(Ntornado/Ntot*100))

# filter data frame
tornado_df = info[info['EVENT_TYPE'] == 'Tornado']

# then let's filter entries without any location info:
tornado_df = tornado_df[tornado_df['BEGIN_LAT'].isna() == False]

print(len(tornado_df), 'out of ', Ntornado, ' events have END_LAT info, or ', len(tornado_df)/Ntornado*100, '%')
# Out:
# 1169 out of  52007  are tornado events, or 2.25%
# 1157 out of  1169  events have END_LAT info, or  98.97348160821214 %

# %%
### make a scatter plot 
fig = px.scatter_geo(
    tornado_df,
    lat="END_LAT",
    lon="END_LON",
    hover_name="END_LOCATION",
    #size="DEATHS_DIRECT",
    #scope="usa",  # Zoom to the United States
    projection="albers usa",
    title="Locations for tornados from year "+inYear
)

fig.update_geos(
    scope="usa",
    projection_type="albers usa"
)

fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## instead of a scatter plot, let's make a density map

fig = px.density_map(
    tornado_df, 
    lat='END_LAT', 
    lon='END_LON', 
    hover_name = 'TOR_F_SCALE',
    #z='MAGNITUDE',         
    radius=5,         
    center=dict(lat=37.0902, lon=-95.7129), # Center coordinates of the US
    zoom=3,             # Initial zoom level to view continental US
    title="Tornado density map from year "+inYear
)

fig.update_geos(
    scope="usa",
    projection_type="albers usa"
)

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
### we can also visualize the location and direct deaths from each tornado event
fig = px.scatter_geo(
    tornado_df,
    lat="END_LAT",
    lon="END_LON",
    hover_name="END_LOCATION",
    size="DEATHS_DIRECT",
    #scope="usa",  # Zoom to the United States
    projection="albers usa",
    title="Locations for tornados from year "+inYear
)

fig.update_geos(
    scope="usa",
    projection_type="albers usa"
)

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # TORNADO DATA COMPLETENESS BY YEAR

# %% [markdown]
# Which features do we want to save?
#
# Description from this site: https://www.ncei.noaa.gov/pub/data/swdi/stormevents/csvfiles/Storm-Data-Export-Format.pdf
#
# LOCATION INFO
#
# **end_lat**
#
# **end_lon**
#
# STRENGTH OF TORNADO
#
# **magnitude** Ex: 0.75, 60, 0.88, 2.75
# measured extent of the magnitude type ~ only used for wind speeds and hail size (e.g. 0.75” of
# hail; 60 mph winds)
#
# **tor_f_scale** Ex: EF0, EF1, EF2, EF3, EF4, EF5
# Enhanced Fujita Scale describes the strength of the tornado based on the amount and type of
# damage caused by the tornado. The F-scale of damage will vary in the destruction area;
# therefore, the highest value of the F-scale is recorded for each event.
# EF0 – Light Damage (40 – 72 mph)
# EF1 – Moderate Damage (73 – 112 mph)
# EF2 – Significant damage (113 – 157 mph)
# EF3 – Severe Damage (158 – 206 mph)
# EF4 – Devastating Damage (207 – 260 mph)
# EF5 – Incredible Damage (261 – 318 mph)
#
# DAMAGE DEALT
#
# **deaths_direct**  Ex: 0, 45, 23
# The number of deaths directly related to the weather event.
#
# **deaths_indirect** Ex: 0, 4, 6
# The number of deaths indirectly related to the weather event
#
# **damage_property** Ex: 10.00K, 0.00K, 10.00M
# The estimated amount of damage to property incurred by the weather event. (e.g. 10.00K =
# \\$10,000; 10.00M = \\$10,000,000)
#
# **damage_crops** Ex: 0.00K, 500.00K, 15.00M
# The estimated amount of damage to crops incurred by the weather event (e.g. 10.00K =
# \\$10,000; 10.00M = \\$10,000,000)

# %%
tornado_df.keys()#['YEARMONTH']
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE'],
#       dtype='str')

# %%
import geopandas as gpd
from shapely.geometry import Point

# change this to where your radar files are stored
gdf = gpd.read_file("/home/dilys/radar_data/WSR-88D_OperationalCoverage_BOB_20260430.shp")

print(gdf.head())
print(gdf.columns)
print(gdf.crs)

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 8))

gdf.plot(
    ax=ax,
    edgecolor='black',
    facecolor=None,
    linewidth=0.5
)

plt.xlim(-125, -66)
plt.ylim(24, 50)

plt.xlabel('LON [$^\circ$]')
plt.ylabel('LAT [$^\circ$]')
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\c'
# <>:26: SyntaxWarning: invalid escape sequence '\c'
# <>:25: SyntaxWarning: invalid escape sequence '\c'
# <>:26: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_254329/3272371765.py:25: SyntaxWarning: invalid escape sequence '\c'
#   plt.xlabel('LON [$^\circ$]')
# /tmp/ipykernel_254329/3272371765.py:26: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('LAT [$^\circ$]')
#    icao beam height                                           geometry
# 0  KJGX    b  10000  MULTIPOLYGON (((-85.47553 31.94777, -85.47553 ...
# 1  RKJK    b  10000  MULTIPOLYGON (((126.90546 34.00253, 126.90546 ...
# 2  KVNX    b  10000  MULTIPOLYGON (((-98.59352 34.78073, -98.59352 ...
# 3  KPAH    b  10000  MULTIPOLYGON (((-88.22587 34.93295, -88.22587 ...
# 4  KSHV    b  10000  MULTIPOLYGON (((-95.45604 30.77889, -95.45769 ...
# Index(['icao', 'beam', 'height', 'geometry'], dtype='str')
# EPSG:4269
# ...

# %%
### need to reproject for correct centroids? 
# https://gis.stackexchange.com/questions/372564/userwarning-when-trying-to-get-centroid-from-a-polygon-geopandas

#reproject = gdf.to_crs(epsg=3395)
radar_coords = reproject.centroid
#radar_coords = gdf['geometry'].centroid

# %%
# Out:
# 0       POINT (-9283350.994 3841254.231)
# 1       POINT (14108348.149 4276452.659)
# 2       POINT (-10936017.724 4383428.47)
# 3       POINT (-9881830.998 4427752.582)
# 4      POINT (-10449515.093 3809051.225)
#                      ...
# 469     POINT (-8249934.845 5233071.959)
# 470     POINT (-9944857.588 4864325.201)
# 471     POINT (-9295642.836 5239759.858)
# 472    POINT (-10377844.351 3501899.747)
# 473     POINT (-9564095.911 3559875.198)
# Length: 474, dtype: geometry

# %%
import pandas as pd

def parse_km(s):
    if s is None:
        return np.nan

    s = str(s).upper().strip()

    if s in {"", "NA", "N/A", "NULL"}:
        return np.nan

    try:
        if s.endswith("K"):
            return float(s[:-1]) * 1_000
        if s.endswith("M"):
            return float(s[:-1]) * 1_000_000
        if s.endswith("B"):
            return float(s[:-1]) * 1_000_000_000
        return float(s)
    except:
        return np.nan


raw_files = glob.glob('./data/raw/StormEvents*')
raw_files = np.sort(raw_files) # will sort chronologically thanks to naming convention
print(raw_files)

savekeys = ['BEGIN_YEARMONTH', 'BEGIN_LAT', 'BEGIN_LON',
            'END_LAT', 'END_LON',
            'TOR_F_SCALE', 
            'DEATHS_DIRECT', 'DEATHS_INDIRECT',
            'INJURIES_DIRECT', 'INJURIES_INDIRECT',
           'DAMAGE_PROPERTY', 'DAMAGE_CROPS']

fig, ax = plt.subplots(len(savekeys),1, figsize=(5,5*len(savekeys)))
plt.subplots_adjust(wspace=0., hspace=0.8)

listsave = []
Nlistsave = []


years_all = []
months_all = []
b_lat = []
b_lon = []
e_lat = []
e_lon = []
tor_all = []
d_direct = []
d_indirect = []
inj_direct = []
inj_indirect = []
d_property = []
d_crops = []
radar_all = []

# data completeness 
for n in raw_files:
    inFile = n
    info = pd.read_csv(inFile, encoding = 'latin-1')
    
    other, inYear = inFile.split('.0_d')
    inYear, other = inYear.split('_c')
    print('====== DATA FOR YEAR: ', inYear, ' ======')
    #store[inYear] = {}

    Ntot = len(info)
    Ntornado = np.sum(info['EVENT_TYPE'] == 'Tornado')
    print(Ntornado, 'out of ', Ntot,  ' are tornado events, or {:.2f}%'.format(Ntornado/Ntot*100))
    
    # filter data frame
    tornado_df = info[info['EVENT_TYPE'] == 'Tornado']

    # then let's filter entries without any location info:
    tornado_df = tornado_df[tornado_df['END_LAT'].isna() == False]
    
    print(len(tornado_df), 'out of ', Ntornado, ' events have END_LAT info, or {:.2f}%'.format( len(tornado_df)/Ntornado*100))

    #print(info.keys())
    years_all.append(int(inYear))
     
    passin_all = []
    passinN_all = []


    # for mm in range(1,len(savekeys)):
    #     filter_arr *= np.array(tornado_df[savekeys[mm]].isna() == False) 

    filter_arr = np.array(tornado_df['BEGIN_LAT'].isna() == False) * np.array(tornado_df['BEGIN_LON'].isna() == False) * np.array(tornado_df['DAMAGE_CROPS'].isna() == False) *  np.array(tornado_df['DAMAGE_PROPERTY'].isna() == False)
    
    m_int = 0
    store = {}
    data_f = tornado_df[filter_arr]
    
    for m in savekeys:
        #store[inYear][m] = tornado_df[m]
        ax[m_int].plot(int(inYear), len(tornado_df[m][tornado_df[m].isna() == False])/Ntornado*100, marker='o', markersize=9, linestyle='', color='red')
        ax[m_int].set_xlabel('Year')
        ax[m_int].set_ylabel('% completeness')
        ax[m_int].set_title(m)
        passin_all.append(len(tornado_df[m][tornado_df[m].isna() == False])/Ntornado*100)
        passinN_all.append(len(tornado_df[m][tornado_df[m].isna() == False]))
        m_int += 1
        years = []
        months = []
        if m == 'BEGIN_YEARMONTH':
            ym = np.asarray(data_f[m], dtype=int)

            years = ym // 100
            months = ym % 100
            store['YEAR'] = years
            store['MONTH'] = months
        else:    
            store[m] = data_f[m]

    lats = data_f['BEGIN_LAT']
    lons = data_f['BEGIN_LON']
    
    points = gpd.GeoDataFrame(
        geometry=[Point(lon, lat) for lon, lat in zip(lons, lats)],
        crs=gdf.crs
    )
    
    joined = gpd.sjoin(
        points,
        gdf,
        predicate="within",
        how="left"
    )
    
    inside_polygon = (
        joined.groupby(joined.index)["index_right"] # prevents duplicates (of points which intersect with lat/lon )
        .apply(lambda x: x.notna().any()) # flags whether any of the points intersects with the lat/lon
        .reindex(points.index, fill_value=False) # for any lat/lon which don't have matches, fill in with False 
        .to_numpy()
    )

    store['DAMAGE_PROPERTY'] = [parse_km(x) for x in store['DAMAGE_PROPERTY']]
    store['DAMAGE_CROPS'] = [parse_km(x) for x in store['DAMAGE_CROPS']]

    store['RADAR_2026'] = inside_polygon


    years_all.append(list(store['YEAR']))
    months_all.append(list(store['MONTH']))
    b_lat.append(list(store['BEGIN_LAT']))
    b_lon.append(list(store['BEGIN_LON']))
    e_lat.append(list(store['END_LAT']))
    e_lon.append(list(store['END_LON']))
    tor_all.append(list(store['TOR_F_SCALE']))
    d_direct.append(list(store['DEATHS_DIRECT']))
    d_indirect.append(list(store['DEATHS_INDIRECT']))
    inj_direct.append(list(store['INJURIES_DIRECT']))
    inj_indirect.append(list(store['INJURIES_INDIRECT']))
    d_property.append(list(store['DAMAGE_PROPERTY']))
    d_crops.append(list(store['DAMAGE_CROPS']))
    radar_all.append(list(store['RADAR_2026']))


    df = pd.DataFrame(store)
    df.to_csv('./data/'+inYear+'_tornados.csv', index=False)
    
    listsave.append(np.array(passin_all))
    Nlistsave.append(np.array(passinN_all))
# Out:
# ['./data/raw/StormEvents_details-ftp_v1.0_d1990_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1991_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1992_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1993_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1994_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1995_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1996_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1997_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1998_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d1999_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2000_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2001_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2002_c20260323.csv.gz'
#  './data/raw/StormEvents_details-ftp_v1.0_d2003_c20260323.csv.gz'
# ...

# %%
tornado_coors = np.transpose(np.array([lons, lats]))

# %%
radar_coords = gdf['geometry'].centroid#np.array([points['geometry'].x, points['geometry'].y])
# Out:
# /tmp/ipykernel_254329/374677773.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   radar_coords = gdf['geometry'].centroid#np.array([points['geometry'].x, points['geometry'].y])

# %%
tornado_coors[0][1], tornado_coors[0][0]#, tornado_coors[1]
# Out:
# (np.float64(41.79), np.float64(-86.1))

# %%
radar_coords

# %%
# Source - https://stackoverflow.com/a/57298327
# Posted by BenT, modified by community. See post 'Timeline' for change history
# Retrieved 2026-06-26, License - CC BY-SA 4.0

import numpy as np

#read in the file, check the data structure using data.shape()
#data = np.genfromtxt(fname) 

#Create the function of the haversine equation with numpy
def haversine(Olat,Olon, Dlat,Dlon):

    radius = 6371.  # km

    d_lat = np.radians(Dlat - Olat)
    d_lon = np.radians(Dlon - Olon)
    a = (np.sin(d_lat / 2.) * np.sin(d_lat / 2.) +
         np.cos(np.radians(Olat)) * np.cos(np.radians(Dlat)) *
         np.sin(d_lon / 2.) * np.sin(d_lon / 2.))
    c = 2. * np.arctan2(np.sqrt(a), np.sqrt(1. - a))
    d = radius * c
    return d

#Call function with your data from some specified point
distance_kpc = np.sort(haversine(tornado_coors[0][1],tornado_coors[0][0], radar_coords[0], radar_coords[1]))

# %%
np.min(distance_kpc), np.max(distance_kpc)
# Out:
# (np.float64(11907.102643268285), np.float64(15698.626984955166))

# %%
save_lists = [years_all, months_all, b_lat, b_lon, e_lat, e_lon, tor_all, d_direct, d_indirect, inj_direct, inj_indirect, d_property, d_crops, radar_all]

flat_list = []
for n in range(0,len(save_lists)):
    flat = [
        x
        for sub in save_lists[n]
        for x in (sub if isinstance(sub, list) else [sub])
    ]
    flat_list.append(flat)

# %%
len(flat_list[0]), len(flat_list[1]), 

### trying to put all together, but not working...
# Out:
# (26105, 26069)

# %%
df = pd.DataFrame({
    'YEAR': flat_list[0], 
    'MONTH': flat_list[1], 
    'BEGIN_LAT': flat_list[2], 
    'BEGIN_LON': flat_list[3], 
    'END_LAT': flat_list[4], 
    'END_LON': flat_list[5], 
    'TOR_F_SCALE': flat_list[6], 
    'DEATHS_DIRECT': flat_list[7], 
    'DEATHS_INDIRECT': flat_list[8], 
    'INJURIES_DIRECT': flat_list[9], 
    'INJURIES_INDIRECT': flat_list[10], 
    'DAMAGE_PROPERTY': flat_list[11], 
    'DAMAGE_CROPS': flat_list[12], 
    'RADAR_2026': flat_list[13], 
})
df.to_csv('./data/tornados_all.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df = pd.DataFrame({
#       2     'YEAR': flat_list[0],
#       3     'MONTH': flat_list[1],
#       4     'BEGIN_LAT': flat_list[2],
#
# File ~/miniconda3/envs/twister/lib/python3.12/site-packages/pandas/core/frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# ...

# %%
plt.figure()
for m in range(0,len(savekeys)):
    plt.plot(years_all, np.transpose(listsave)[m], label=savekeys[m])
plt.xlabel('Year')
plt.ylabel('% complete')
plt.legend(fontsize=15, bbox_to_anchor=(1., 0.1), loc = 'lower left')

plt.figure()
for m in range(0,len(savekeys)):
    plt.plot(years_all, np.transpose(Nlistsave)[m], label=savekeys[m])
plt.xlabel('Year')
plt.ylabel('# events with valid data')
plt.yscale('log')
plt.legend(fontsize=15, bbox_to_anchor=(1., 0.1), loc = 'lower left')

# %%
import json

# Open the file and load its contents
with open('./data/raw/nexrad_sites.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# The data is now a standard Python dictionary or list
print(data)
# Out:
# {'type': 'FeatureCollection', 'features': [{'id': 'https://api.weather.gov/radar/stations/KOKX', 'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-72.86392, 40.86552]}, 'properties': {'@id': 'https://api.weather.gov/radar/stations/KOKX', '@type': 'wx:RadarStation', 'id': 'KOKX', 'name': 'Brookhaven', 'stationType': 'WSR-88D', 'elevation': {'unitCode': 'wmoUnit:m', 'value': 25.91}, 'timeZone': 'GMT', 'latency': {'current': {'unitCode': 'nwsUnit:s', 'value': 0.383728}, 'average': {'unitCode': 'nwsUnit:s', 'value': 0.14}, 'max': {'unitCode': 'nwsUnit:s', 'value': 0}, 'levelTwoLastReceivedTime': '2026-05-28T15:09:57+00:00', 'maxLatencyTime': '2026-05-28T15:08:09+00:00', 'reportingHost': 'rdss', 'host': 'ldm4'}, 'rda': {'timestamp': '2026-05-28T15:08:18+00:00', 'reportingHost': 'rdss', 'properties': {'resolutionVersion': 6, 'nl2Path': 'Default', 'volumeCoveragePattern': 'R35', 'controlStatus': 'RPG (Remote) Only', 'buildNumber': 24.1, 'alarmSummary': 'No Alarms', 'mode': '
# ...

# %%
str(data['features'][1]['properties']['rda']['properties']['status']) == 'Operate'#.keys()#[1]['rda']#['status']#[n]#['status']
# Out:
# True

# %%
radar = pd.DataFrame(data['features'])

radar_names = radar['id']

dict_radar = {}
rad_lon = []
rad_lat = []
rad_name = []

for n in range(0,len(radar_names)):
    id_name = data['features'][n]['properties']['name']
    if data['features'][n]['properties']['rda'] == None:
        print(id_name, ' has no rda info')
    elif str(data['features'][n]['properties']['rda']['properties']['status']) == 'Operate':
        dict_radar[id_name] = {}
        coordinates = data['features'][n]['geometry']['coordinates']
        dict_radar[id_name]['LAT'] = coordinates[1]
        dict_radar[id_name]['LON'] = coordinates[0]
    
        rad_name.append(id_name)
        rad_lon.append(coordinates[0])
        rad_lat.append(coordinates[1])

print(len(rad_name), ' out of ', len(radar_names), ' have status == Operate')

df_radars = {
    'Name': rad_name,
    'LAT': rad_lat,
    'LON': rad_lon,
    'RANGE_km': [430]*len(rad_name)
}
# Out:
# Kadena AB  has no rda info
# 152  out of  159  have status == Operate

# %%
points = np.transpose([rad_lat, rad_lon])

# %%
from pyproj import Geod
from shapely.geometry import Polygon
import numpy as np

geod = Geod(ellps="WGS84")

### you have to calculate geodesics for projections to be correct
def geodesic_circle(lat, lon, radius_m=430000, n_points=180):
    """
    Create a geodesic circle polygon around (lat, lon)
    with radius in meters.
    """
    angles = np.linspace(0, 360, n_points)

    lons, lats = geod.fwd(
        [lon] * n_points,
        [lat] * n_points,
        angles,
        [radius_m] * n_points
    )[:2]

    return Polygon(zip(lons, lats))


circles = [geodesic_circle(lat, lon) for lat, lon in points]

import plotly.graph_objects as go

fig = go.Figure()

for poly in circles:
    lon, lat = poly.exterior.xy

    fig.add_trace(go.Scattergeo(
        lon=list(lon),
        lat=list(lat),
        fill="toself",
        mode="lines",
        line=dict(width=1),
        opacity=0.3
    ))

# Add center points on top
fig.add_trace(go.Scattergeo(
    lon=[lon for lat, lon in points],
    lat=[lat for lat, lon in points],
    mode="markers",
    marker=dict(size=6, color="red")
))

fig.update_layout(
    title="Radar Locations with max range of 430 km",
    geo=dict(
        projection_type="albers usa"
    )
)

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## CENSUS INFORMATION
df_cen = pd.read_csv('./data/raw/co-est2023-alldata.csv', encoding='latin-1')
df_cen
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3190      50       4         8     56      37  Wyoming  Sweetwater County
# 3191      50       4         8     56      39  Wyoming       Teton County
# 3192      50       4         8     56      41  Wyoming       Uinta County
# 3193      50       4         8     56      43  Wyoming    Washakie County
# 3194      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  \
# ...

# %%
fips_all = []
for n in range(0,len(df_cen['CTYNAME'])):
    entry = n
    if len(str(df_cen['STATE'][entry])) < 2:
        state_id = '0'+str(df_cen['STATE'][entry])
    elif len(str(df_cen['STATE'][entry])) == 2:
        state_id = str(df_cen['STATE'][entry])
    
    if len(str(df_cen['COUNTY'][entry])) < 2:
        cnty_id = '00'+str(df_cen['COUNTY'][entry])
    elif (len(str(df_cen['COUNTY'][entry])) < 3) and (len(str(df_cen['COUNTY'][entry])) >= 2):
        cnty_id = '0'+str(df_cen['COUNTY'][entry])
    elif (len(str(df_cen['COUNTY'][entry])) == 3):
        cnty_id = str(df_cen['COUNTY'][entry])
    
    FIPS = state_id+cnty_id
    fips_all.append(FIPS)
    print(df_cen['CTYNAME'][entry], ', ', df_cen['STNAME'][entry], FIPS)
# Out:
# Alabama ,  Alabama 01000
# Autauga County ,  Alabama 01001
# Baldwin County ,  Alabama 01003
# Barbour County ,  Alabama 01005
# Bibb County ,  Alabama 01007
# Blount County ,  Alabama 01009
# Bullock County ,  Alabama 01011
# Butler County ,  Alabama 01013
# Calhoun County ,  Alabama 01015
# Chambers County ,  Alabama 01017
# Cherokee County ,  Alabama 01019
# Chilton County ,  Alabama 01021
# Choctaw County ,  Alabama 01023
# Clarke County ,  Alabama 01025
# Clay County ,  Alabama 01027
# Cleburne County ,  Alabama 01029
# Coffee County ,  Alabama 01031
# Colbert County ,  Alabama 01033
# Conecuh County ,  Alabama 01035
# Coosa County ,  Alabama 01037
# Covington County ,  Alabama 01039
# Crenshaw County ,  Alabama 01041
# Cullman County ,  Alabama 01043
# Dale County ,  Alabama 01045
# Dallas County ,  Alabama 01047
# DeKalb County ,  Alabama 01049
# Elmore County ,  Alabama 01051
# Escambia County ,  Alabama 01053
# Etowah County ,  Alabama 01055
# ...

# %%
df_cen['FIPS'] = fips_all
df_cen
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3190      50       4         8     56      37  Wyoming  Sweetwater County
# 3191      50       4         8     56      39  Wyoming       Teton County
# 3192      50       4         8     56      41  Wyoming       Uinta County
# 3193      50       4         8     56      43  Wyoming    Washakie County
# 3194      50       4         8     56      45  Wyoming      Weston County
#
#       ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  \
# ...

# %%
### determine FIPS code for each tornado 

import requests
from urllib.parse import urlencode


years = list(store.keys())

for n in range(0,1):#len(years)):
    
    lat_pass = np.float64(store[years[n]]['BEGIN_LAT'])[0]
    lon_pass = np.float64(store[years[n]]['BEGIN_LON'])[0]

    FIPS_tor = []
    POP23_tor = []
    # for nn in range(0,len(lat_pass)):
    #     lat = lat_pass[nn]
    #     lon = lon_pass[nn]
        
    
    params = urlencode({'latitude': lat_pass, 'longitude':lon_pass, 'format':'json'})
    #Contruct request URL
    url = 'https://geo.fcc.gov/api/census/block/find?' + params
    
    #Get response from API
    response = requests.get(url)
    
    #Parse json in response
    data = response.json()
    
    #print(data['County']['FIPS'])
    fips_pass = data['County']['FIPS']
    FIPS_tor = fips_pass#.append(fips_pass)

    # determine population of county corresponding to lat and lon of tornado event
    
    POP23_tor = df_cen['POPESTIMATE2023'][np.where(df_cen['FIPS'] == str(fips_pass))[0][0])])
    print(lat, lon, FIPS_tor[-1], POP23_tor[-1])
    store[years[n]]['FIPS'] = FIPS_tor
    store[years[n]]['POP23'] = POP23_tor

# %%
### example from this website https://plotly.com/python/tile-county-choropleth/

from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv",
                   dtype={"fips": str})

import plotly.express as px

fig = px.choropleth_map(df, geojson=counties, locations='fips', color='unemp',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           map_style="carto-positron",
                           zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                           opacity=0.5,
                           labels={'unemp':'unemployment rate'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# import pandas as pd
# df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv",
#                    dtype={"fips": str})

fig = px.choropleth_map(df_cen, geojson=counties, 
                        locations='FIPS', color='POPESTIMATE2021',
                        range_color=(0, np.max(df_cen['POPESTIMATE2021'])),
                           map_style="carto-positron",
                           zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                           opacity=.9,
                           labels={'CTYNAME'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import urllib.request
from pathlib import Path
import argparse
import io

# ### 06/22/2026 # Dilys: I had to set this for geopandas to work
# import os
# os.environ["PROJ_DATA"]  = "/home/dilys/miniconda3/envs/twister/share/proj"
# ###

import geopandas as gpd

# %%
def main(zip_url: str, output: str) -> None:
    
    print("Downloading ZIP...")
    with urllib.request.urlopen(ZIP_URL) as r:
        data = r.read()

    print("Creating GeoDataFrame...")
    gdf = gpd.read_file(io.BytesIO(data))
    
    output = Path(output)
    output.parent.mkdir(parents=True, exist_ok=True)
    
    print(f"Saving to {output}...")
    gdf.to_file(output)
    
def parse_arguments():
    
    ZIP_URL = (
        "https://www.roc.noaa.gov/public-documents/shapefiles/" # taken from https://www.roc.noaa.gov/branches/program-branch/site-id-database/site-id-location-maps.php
        "WSR-88D_OperationalCoverage_BOB_20260430.zip"
    )
    
    parser = argparse.ArgumentParser(description="Download NEXRAD coverage into a GeoDataFrame.")
    parser.add_argument('--zip-url', 
                        type=str, 
                        help='URL to zip file containing the shapefile of NEXRAD coverage.',
                        default=ZIP_URL,
    )
    parser.add_argument('--output',
                        '-o', 
                        type=str, 
                        help='Path to output file.', 
                        default='./data/coverage/WSR-88D_OperationalCoverage_BOB_20260430.shp'
    )
    args = parser.parse_args()
    
    return args

if __name__ == "__main__":
    
    args = parse_arguments()
    ZIP_URL = args.zip_url
    main(**vars(args))
# Out:
# usage: ipykernel_launcher.py [-h] [--zip-url ZIP_URL] [--output OUTPUT]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/dilys/.local/share/jupyter/runtime/kernel-cb5a87cb-0e83-4823-af72-e4eb6691cf95.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/dilys/miniconda3/envs/twister/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
data

# %%
ZIP_URL = (
        "https://www.roc.noaa.gov/public-documents/shapefiles/" # taken from https://www.roc.noaa.gov/branches/program-branch/site-id-database/site-id-location-maps.php
        "WSR-88D_OperationalCoverage_BOB_20260430.zip"
    )

print("Downloading ZIP...")
with urllib.request.urlopen(ZIP_URL) as r:
    data = r.read()

print("Creating GeoDataFrame...")
gdf = gpd.read_file(io.BytesIO(data))

output = './data/'

print(f"Saving to {output}...")
gdf.to_file(output)
# Out:
# ...
# Creating GeoDataFrame...
# ERROR 1: PROJ: proj_create_from_database: /home/dilys/miniconda3/envs/twister/lib/python3.12/site-packages/pyogrio/proj_data/proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 5 whereas a number >= 6 is expected. It comes from another PROJ installation.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 11
#       7 with urllib.request.urlopen(ZIP_URL) as r:
#       8     data = r.read()
#       9
#      10 print("Creating GeoDataFrame...")
# ---> 11 gdf = gpd.read_file(io.BytesIO(data))
#      12
#      13 output = './data/'
#      14
#
# File ~/miniconda3/envs/twister/lib/python3.12/site-packages/geopandas/io/file.py:289, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     197 def _read_file(
#     198     filename, bbox=None, mask=None, columns=None, rows=None, engine=None, **kwargs
#     199 ):
# ...
